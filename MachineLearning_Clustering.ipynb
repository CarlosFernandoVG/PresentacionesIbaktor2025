# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Cargar dataset Iris
iris = sns.load_dataset("iris")
X = iris.drop("species", axis=1)

# %%
# Aplicar KMeans con 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X)

# %%
# Evaluación con índice de silueta
score = silhouette_score(X, clusters)
print("Índice de Silueta:", score)
# Out:
# Índice de Silueta: 0.5511916046195922

# %%
# Visualización
plt.figure(figsize=(8,6))
plt.scatter(X.iloc[:,0], X.iloc[:,1], c=clusters, cmap="viridis", edgecolor="k")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("KMeans Clustering - Iris")
plt.show()
